# %%
# !pip install pipreqs
# !pip install guppy3
# %matplotlib inline
# Out:
# Collecting pipreqs
#   Downloading https://files.pythonhosted.org/packages/9b/83/b1560948400a07ec094a15c2f64587b70e1a5ab5f7b375ba902fcab5b6c3/pipreqs-0.4.10-py2.py3-none-any.whl
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from pipreqs) (0.6.2)
# Collecting yarg
#   Downloading https://files.pythonhosted.org/packages/8b/90/89a2ff242ccab6a24fbab18dbbabc67c51a6f0ed01f9a0f41689dc177419/yarg-0.1.9-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (2.10)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.10 yarg-0.1.9
# Collecting guppy3
#   Downloading https://files.pythonhosted.org/packages/10/8f/ae8ddf9a61491d64c4e16871225b30bf2524d0e54d2d8354852e6b066947/guppy3-3.1.0-cp36-cp36m-manylinux2010_x86_64.whl (605kB)
#      |████████████████████████████████| 614kB 10.7MB/s
# Installing collected packages: guppy3
# Successfully installed guppy3-3.1.0

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive/project")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %run main.py --load "models/fusionModel" --eval "fusion"
# Out:
# device : cpu
#
# download file from https://archive.ics.uci.edu/ml/machine-learning-databases/character-trajectories/mixoutALL_shifted.mat
# file already exists
#
# creating patches
# HBox(children=(FloatProgress(value=0.0, max=2143.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=715.0), HTML(value='')))
# training network
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# epoch: 15, train loss: 0.171, val loss: 0.302
# epoch: 30, train loss: 0.055, val loss: 0.162
# epoch: 45, train loss: 0.020, val loss: 0.171
# Finished Training
# evaluation results on train data
# HBox(children=(FloatProgress(value=0.0, max=2143.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9926    1.0000    0.9963       134
#            1     0.9810    0.9904    0.9856       104
#            2     0.9910    1.0000    0.9955       110
#            3     0.9919    0.9919    0.9919       123
#            4     1.0000    0.9863    0.9931       146
#            5     1.0000    1.0000    1.0000        97
#            6     0.9556    0.9556    0.9556        90
#            7     1.0000    0.9919    0.9959       123
#            8     0.9885    0.9885    0.9885        87
#            9     0.9300    0.9490    0.9394        98
#           10     0.9823    0.9823    0.9823       113
#           11     1.0000    1.0000    1.0000        95
#           12     1.0000    0.9889    0.9944        90
#           13     0.9884    0.9551    0.9714        89
#           14     1.0000    1.0000    1.0000        93
#           15     1.0000    0.9630    0.9811       108
#           16     0.9655    0.9912    0.9782       113
#           17     0.9462    0.9670    0.9565        91
#           18     1.0000    1.0000    1.0000       106
#           19     0.9851    0.9925    0.9888       133
#
#     accuracy                         0.9855      2143
#    macro avg     0.9849    0.9847    0.9847      2143
# weighted avg     0.9857    0.9855    0.9856      2143
#
# evaluation results on test data
# HBox(children=(FloatProgress(value=0.0, max=715.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        37
#            1     0.9231    0.9730    0.9474        37
#            2     0.8649    1.0000    0.9275        32
#            3     1.0000    1.0000    1.0000        34
#            4     1.0000    1.0000    1.0000        40
#            5     0.9750    0.9512    0.9630        41
#            6     1.0000    0.9730    0.9863        37
#            7     1.0000    0.9412    0.9697        51
#            8     0.9730    0.9474    0.9600        38
#            9     0.9333    0.8750    0.9032        32
#           10     0.9655    1.0000    0.9825        28
#           11     0.9189    0.9444    0.9315        36
#           12     0.9444    1.0000    0.9714        34
#           13     1.0000    0.8333    0.9091        30
#           14     1.0000    0.9750    0.9873        40
#           15     0.8846    1.0000    0.9388        23
#           16     0.9302    0.9524    0.9412        42
#           17     0.9355    0.8529    0.8923        34
#           18     1.0000    0.9677    0.9836        31
#           19     0.9024    0.9737    0.9367        38
#
#     accuracy                         0.9580       715
#    macro avg     0.9575    0.9580    0.9566       715
# weighted avg     0.9600    0.9580    0.9579       715
# HBox(children=(FloatProgress(value=0.0, max=40717.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13585.0), HTML(value='')))
# training network
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# epoch: 15, train loss: 0.061, val loss: 0.154
# epoch: 30, train loss: 0.033, val loss: 0.147
# epoch: 45, train loss: 0.026, val loss: 0.130
# epoch: 60, train loss: 0.018, val loss: 0.145
# Finished Training
# evaluation results on train data
# HBox(children=(FloatProgress(value=0.0, max=2143.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9781    1.0000    0.9889       134
#            1     0.9810    0.9904    0.9856       104
#            2     1.0000    1.0000    1.0000       110
#            3     0.9919    1.0000    0.9960       123
#            4     1.0000    1.0000    1.0000       146
#            5     0.9898    1.0000    0.9949        97
#            6     0.9670    0.9778    0.9724        90
#            7     1.0000    1.0000    1.0000       123
#            8     0.9885    0.9885    0.9885        87
#            9     0.9412    0.9796    0.9600        98
#           10     1.0000    0.9469    0.9727       113
#           11     1.0000    1.0000    1.0000        95
#           12     1.0000    0.9889    0.9944        90
#           13     0.9884    0.9551    0.9714        89
#           14     1.0000    1.0000    1.0000        93
#           15     1.0000    0.9722    0.9859       108
#           16     0.9912    0.9912    0.9912       113
#           17     0.9457    0.9560    0.9508        91
#           18     1.0000    1.0000    1.0000       106
#           19     0.9925    1.0000    0.9963       133
#
#     accuracy                         0.9883      2143
#    macro avg     0.9878    0.9873    0.9874      2143
# weighted avg     0.9885    0.9883    0.9883      2143
#
# evaluation results on test data
# HBox(children=(FloatProgress(value=0.0, max=715.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9737    1.0000    0.9867        37
#            1     0.9730    0.9730    0.9730        37
#            2     0.9412    1.0000    0.9697        32
#            3     1.0000    1.0000    1.0000        34
#            4     1.0000    1.0000    1.0000        40
#            5     1.0000    0.9756    0.9877        41
#            6     0.9459    0.9459    0.9459        37
#            7     1.0000    0.9608    0.9800        51
#            8     0.9730    0.9474    0.9600        38
#            9     0.8966    0.8125    0.8525        32
#           10     1.0000    1.0000    1.0000        28
#           11     0.9722    0.9722    0.9722        36
#           12     0.9706    0.9706    0.9706        34
#           13     0.9630    0.8667    0.9123        30
#           14     1.0000    1.0000    1.0000        40
#           15     0.8846    1.0000    0.9388        23
#           16     0.9767    1.0000    0.9882        42
#           17     0.9091    0.8824    0.8955        34
#           18     1.0000    1.0000    1.0000        31
#           19     0.9048    1.0000    0.9500        38
#
#     accuracy                         0.9664       715
#    macro avg     0.9642    0.9654    0.9642       715
# weighted avg     0.9669    0.9664    0.9661       715
#
# evaluation results on train data
# HBox(children=(FloatProgress(value=0.0, max=2143.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9624    0.9552    0.9588       134
#            1     0.9300    0.8942    0.9118       104
#            2     0.9908    0.9818    0.9863       110
#            3     0.9919    0.9919    0.9919       123
#            4     0.9660    0.9726    0.9693       146
#            5     0.9510    1.0000    0.9749        97
#            6     0.9451    0.9556    0.9503        90
#            7     0.9531    0.9919    0.9721       123
#            8     0.9663    0.9885    0.9773        87
#            9     0.9126    0.9592    0.9353        98
#           10     0.8148    0.9735    0.8871       113
#           11     0.9895    0.9895    0.9895        95
#           12     0.9263    0.9778    0.9514        90
#           13     0.9647    0.9213    0.9425        89
#           14     1.0000    1.0000    1.0000        93
#           15     0.9813    0.9722    0.9767       108
#           16     0.9818    0.9558    0.9686       113
#           17     1.0000    0.7143    0.8333        91
#           18     0.9633    0.9906    0.9767       106
#           19     0.9677    0.9023    0.9339       133
#
#     accuracy                         0.9557      2143
#    macro avg     0.9579    0.9544    0.9544      2143
# weighted avg     0.9579    0.9557    0.9552      2143
#
# evaluation results on test data
# HBox(children=(FloatProgress(value=0.0, max=715.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9375    0.8108    0.8696        37
#            1     0.8718    0.9189    0.8947        37
#            2     0.9697    1.0000    0.9846        32
#            3     1.0000    0.9706    0.9851        34
#            4     0.9756    1.0000    0.9877        40
#            5     0.9091    0.9756    0.9412        41
#            6     1.0000    0.8649    0.9275        37
#            7     0.9444    1.0000    0.9714        51
#            8     0.9737    0.9737    0.9737        38
#            9     0.8750    0.8750    0.8750        32
#           10     0.7568    1.0000    0.8615        28
#           11     0.9167    0.9167    0.9167        36
#           12     0.8947    1.0000    0.9444        34
#           13     0.8929    0.8333    0.8621        30
#           14     1.0000    1.0000    1.0000        40
#           15     0.8214    1.0000    0.9020        23
#           16     0.9756    0.9524    0.9639        42
#           17     0.9565    0.6471    0.7719        34
#           18     0.9355    0.9355    0.9355        31
#           19     0.8857    0.8158    0.8493        38
#
#     accuracy                         0.9259       715
#    macro avg     0.9246    0.9245    0.9209       715
# weighted avg     0.9299    0.9259    0.9246       715

# %%
# !pipreqs --savepath "/content/drive/MyDrive/project/req.txt"

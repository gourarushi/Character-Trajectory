# %%
# !pip install pipreqs
# !pip install guppy3
# %matplotlib inline
# Out:
# Collecting pipreqs
#   Downloading https://files.pythonhosted.org/packages/9b/83/b1560948400a07ec094a15c2f64587b70e1a5ab5f7b375ba902fcab5b6c3/pipreqs-0.4.10-py2.py3-none-any.whl
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from pipreqs) (0.6.2)
# Collecting yarg
#   Downloading https://files.pythonhosted.org/packages/8b/90/89a2ff242ccab6a24fbab18dbbabc67c51a6f0ed01f9a0f41689dc177419/yarg-0.1.9-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.10 yarg-0.1.9
# Collecting guppy3
#   Downloading https://files.pythonhosted.org/packages/10/8f/ae8ddf9a61491d64c4e16871225b30bf2524d0e54d2d8354852e6b066947/guppy3-3.1.0-cp36-cp36m-manylinux2010_x86_64.whl (605kB)
#      |████████████████████████████████| 614kB 16.2MB/s
# Installing collected packages: guppy3
# Successfully installed guppy3-3.1.0

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive/project")
# Out:
# Mounted at /content/drive

# %%
# %run main.py  --dataset "Anomaly"\
              --load "models/latentModel"\
              --eval "latent"
# Out:
# device : cuda:0
#
# download file from https://drive.google.com/u/0/uc?id=1CdYxeX8g9wxzSnz6R51ELmJJuuZ3xlqa&export=download
# file already exists
#
# creating patches
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# training network
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# epoch: 15, train loss: 0.140, val loss: 0.141
# epoch: 30, train loss: 0.129, val loss: 0.133
# epoch: 45, train loss: 0.123, val loss: 0.141
# epoch: 60, train loss: 0.119, val loss: 0.127
# epoch: 75, train loss: 0.116, val loss: 0.126
# epoch: 90, train loss: 0.113, val loss: 0.129
# epoch: 105, train loss: 0.111, val loss: 0.125
# epoch: 120, train loss: 0.107, val loss: 0.125
# Finished Training
# evaluation results on train data
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9676    0.9976    0.9824     41642
#            1     0.9859    0.8338    0.9035      8358
#
#     accuracy                         0.9702     50000
#    macro avg     0.9767    0.9157    0.9429     50000
# weighted avg     0.9707    0.9702    0.9692     50000
#
# evaluation results on test data
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9652    0.9958    0.9803      8304
#            1     0.9756    0.8243    0.8936      1696
#
#     accuracy                         0.9667     10000
#    macro avg     0.9704    0.9100    0.9369     10000
# weighted avg     0.9670    0.9667    0.9656     10000
# HBox(children=(FloatProgress(value=0.0, max=200000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40000.0), HTML(value='')))
# forming clusters... done
# training network
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# epoch: 15, train loss: 0.169, val loss: 0.171
# epoch: 30, train loss: 0.120, val loss: 0.124
# epoch: 45, train loss: 0.105, val loss: 0.119
# epoch: 60, train loss: 0.098, val loss: 0.118
# Finished Training
# evaluation results on train data
# HBox(children=(FloatProgress(value=0.0, max=200000.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9682    0.9577    0.9629     28060
#            1     0.8688    0.9733    0.9181       449
#            2     0.9720    0.9739    0.9730     38588
#            3     0.9883    0.9251    0.9557       641
#            4     0.8997    0.9801    0.9382       302
#            5     0.9967    0.7426    0.8511       408
#            6     0.9468    0.9571    0.9519     12765
#            7     0.9502    0.9344    0.9422     17153
#            8     0.9703    0.8977    0.9326      1202
#            9     0.8886    0.9782    0.9313      1191
#           10     0.9690    0.9224    0.9452      1289
#           11     0.9653    0.9047    0.9340       430
#           12     0.9668    0.9668    0.9668       391
#           13     0.8432    0.9505    0.8936      1171
#           14     0.9629    0.9679    0.9654     28946
#           15     0.9598    0.9468    0.9533      1034
#           16     0.9541    0.9548    0.9545     13201
#           17     0.9263    0.9393    0.9327       428
#           18     0.9543    0.9338    0.9440     15277
#           19     0.9649    0.9786    0.9717     37074
#
#     accuracy                         0.9609    200000
#    macro avg     0.9458    0.9393    0.9409    200000
# weighted avg     0.9611    0.9609    0.9609    200000
#
# evaluation results on test data
# HBox(children=(FloatProgress(value=0.0, max=40000.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0     0.9616    0.9526    0.9571      5650
#            1     0.8491    0.9574    0.9000        94
#            2     0.9737    0.9754    0.9746      7716
#            3     0.9926    0.8428    0.9116       159
#            4     0.8250    0.9706    0.8919        34
#            5     1.0000    0.6974    0.8217        76
#            6     0.9377    0.9504    0.9440      2520
#            7     0.9454    0.9219    0.9335      3379
#            8     0.9592    0.8902    0.9234       264
#            9     0.8874    0.9710    0.9273       276
#           10     0.9673    0.9331    0.9499       254
#           11     0.9479    0.8349    0.8878       109
#           12     0.9419    0.9643    0.9529        84
#           13     0.7814    0.9061    0.8391       213
#           14     0.9627    0.9648    0.9638      5856
#           15     0.9490    0.9118    0.9300       204
#           16     0.9349    0.9486    0.9417      2588
#           17     0.8842    0.9545    0.9180        88
#           18     0.9548    0.9326    0.9436      2967
#           19     0.9602    0.9752    0.9677      7469
#
#     accuracy                         0.9565     40000
#    macro avg     0.9308    0.9228    0.9240     40000
# weighted avg     0.9568    0.9565    0.9564     40000

# %%
# !pipreqs --savepath "/content/drive/MyDrive/project/req.txt"

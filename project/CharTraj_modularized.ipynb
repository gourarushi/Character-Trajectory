# %%
# !pip install pipreqs
# !pip install guppy3
# %matplotlib inline
# Out:
# ...
#      |████████████████████████████████| 614kB 6.5MB/s
# ...

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive/project")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %run main.py  --dataset "Anomaly"\
              --saveFusion "models/fusionModel"\
              --train "fusion"
# Out:
# device : cpu
#
# download file from https://drive.google.com/u/0/uc?id=1CdYxeX8g9wxzSnz6R51ELmJJuuZ3xlqa&export=download
# file already exists
#
# creating patches
# ...
# training network
# ...
# epoch: 15, train loss: 0.141, val loss: 0.142
# epoch: 30, train loss: 0.126, val loss: 0.129
# epoch: 45, train loss: 0.120, val loss: 0.129
# epoch: 60, train loss: 0.117, val loss: 0.125
# epoch: 75, train loss: 0.115, val loss: 0.125
# Finished Training
# evaluation results on train data
# ...
#               precision    recall  f1-score   support
#
#            0     0.9678    0.9963    0.9819     41642
#            1     0.9784    0.8350    0.9010      8358
#
#     accuracy                         0.9693     50000
#    macro avg     0.9731    0.9157    0.9414     50000
# weighted avg     0.9696    0.9693    0.9683     50000
#
# evaluation results on test data
# ...
#               precision    recall  f1-score   support
#
#            0     0.9668    0.9945    0.9804      8304
# ...

# %%
# !pipreqs --savepath "/content/drive/MyDrive/project/req.txt"
